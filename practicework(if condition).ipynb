# %%
#Positve(or)negative excercise
a=10
b=-10
if a>=0:
    print("a is positive number")
elif a<=0:
    print("a is negative number")
    if b>=0:
        print("b is positve number")
elif b<=0:
    print("b is negative number")
else:
    print("otherwice negative number")
# Out:
# a is positive number

# %%
#biggeet number
a=10
b=19
if a>b:
    print("a is bigger number")
elif b>a:
    print("b is bigger number")
else:
    print("otherwise  same number")
# Out:
# b is bigger number

# %%
#Even and odd number
a=13
b=60
if a%2==0:
    print("a number is even number")
else:
    print("a number is odd number")
    if b%2==0:
        print("b number is even number")
    else:
        print("b number is odd number")
# Out:
# a number is odd number
# b number is even number

# %%
# student mark
mark=int(input("enter your mark:"))
if mark>=35:
    print("Result is also pass")
else:
    print("Result is also fail")
# Out:
# enter your mark: 12
# Result is also fail

# %%
#vote if concept
age=int(input("enter your age:"))
if age>=18:
    print("you are eligible for vote")
else:
    print("you are not eligible for vote")
# Out:
# enter your age: 20
# you are eligible for vote
