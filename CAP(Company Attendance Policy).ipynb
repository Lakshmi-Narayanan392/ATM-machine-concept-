# %%
### Discpline_mark=100
attendance_mark=100
perfomance_mark=100
Discpline_mark=int(input("enter your Discpline mark:"))
if Discpline_mark>=100:
    print("10% bonus allowed")
elif Discpline_mark>=80:
    print("5% bonus allowed")
attendance_mark=int(input("enter your attendance mark:"))
if attendance_mark>=100:
    print("10% bonus allowed")
elif attendance_mark>=80:
    print("5% bonus allowed")
perfomance_mark=int(input("enter your perfomance mark:"))
if perfomance_mark>=100:
    print("10% bonus allowed")
elif perfomance_mark>=80:
    print("5% bonus allowed")
else:
    total=("Discpline_mark,attendance_mark,perfomance_mark is low:")
    print("2% otherwise bonus allowed:")
# Out:
# enter your Discpline mark: 80
# 5% bonus allowed
# enter your attendance mark: 30
# enter your perfomance mark: 10
# 2% otherwise bonus allowed:
