# %%
stop = input("Enter stop name (1-Vilupuram,2-Trichy,3-dindigul,4-maduri,5-thoothukudi,6-tirunelveli,7-kumari: ")
if stop=="vilupuram" or stop=="1":
    print("pay 100 rs only")
elif stop == "trichy" or stop=="2":
    print("city name Trichy pay 200 rs only")
elif stop == "dindigul" or stop=="3":
    print("city name dindigul pay 300 rs only")
elif stop == "madurai" or stop=="4":
    print("city name  madurai pay 400 rs only")
elif stop == "thoothkudi" or stop=="5":
    print("city name thoothkudi pay 500 rs only")
elif stop == "tirunelveli" or stop=="6":
    print("city name tirunelveli pay 600 rs only")
elif stop == "kumari" or stop=="7":
    print("city name kumari pay 600 rs only")
else:
    print("happy journey")
# Out:
# Enter stop name (1-Vilupuram,2-Trichy,3-dindigul,4-maduri,5-thoothukudi,6-tirunelveli,7-kumari:  3
# city name dindigul pay 300 rs only

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\TNQ
